# %% [markdown]
# # My first Jupyter Notebook
#
#
# - we beginn to import some useful packeges
#     - [NumPy](https://numpy.org/devdocs/user/quickstart.html "NumPy Tutorial")
#     - [Matplotlib](https://matplotlib.org "Matplotlib Tutorial")
#
# In order to programm
# ```python
# x=np.array(np.arange(100))
#
# a=np.sin(x)
# b=np.cos(np.pi*x)
# f=a*b
# ```
# and visualize
# ```python
# plt.plot(x,f)
# ```
# specific sintific problems :
#
# $$\int_a^bf(x)g(x)dx=
# \begin{cases}
#     0, & \text{if } i\neq j\\
#     c \geq 0, & \text{if } i= j
# \end{cases}0$$
#
#
#    - In a Markdown you can also write formulas in line $f(x)=\cos(x)$.
#
# ## my fist subtitle
#
# ![Fig. 1.](Desktop/firstpic.png)
# ##### Fig. 1 import a image. make sure that firstpic.png is placed in the same directory or give the path to the image.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.array(np.arange(10))

a=np.sin(x)
b=np.cos(np.pi*x)
f=a*b

print(f[9])
# Out:
# -0.4121184852417566

# %%
plt.plot(x,a)
plt.plot(x,b)
plt.plot(x,f)
